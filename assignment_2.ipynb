# %%
for i in range(1,6):
  print ('*' * i)
for x in range(4,0 ,-1):
 print('*' * x)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
i = input("enter the string")
a =  i[::-1]
print(a)
# Out:
# enter the string iNeuron
# norueNi
